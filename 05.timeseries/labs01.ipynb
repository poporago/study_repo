# %%
import os
os.getcwd()
# Out:
# 'c:\\ydsc\\study_repo\\05.timeseries'

# %%
import pandas as pd 

df = pd.read_csv('산업별_취업자_20210206234505.csv', encoding='euc-kr')
# Out:
#           시점      계  P 교육 서비스업(85)
# 0   2013. 01  24287           1710
# 1   2013. 02  24215           1681
# 2   2013. 03  24736           1716
# 3   2013. 04  25322           1745
# 4   2013. 05  25610           1774
# ..       ...    ...            ...
# 91  2020. 08  27085           1793
# 92  2020. 09  27012           1768
# 93  2020. 10  27088           1772
# 94  2020. 11  27241           1785
# 95  2020. 12  26526           1777
#
# [96 rows x 3 columns]

# %%
df.columns = ['t','total' ,'value']

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=1 , ncols=2)

axes[0].plot(df['total'])
axes[1].plot(df['value'])
