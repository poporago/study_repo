# %% [markdown]
# 1. COLOR SET

# %%
import matplotlib.colors as mcolors

print("mcolors.BASE_COLORS['r']: {}, type={}".format(mcolors.BASE_COLORS['r'], type(mcolors.BASE_COLORS['r'])))
print("mcolors.TABLEAU_COLORS['tab:red']: {}, type={}".format(mcolors.TABLEAU_COLORS['tab:red'], type(mcolors.TABLEAU_COLORS['tab:red'])))
print("mcolors.CSS4_COLORS['red']: {}, type={}".format(mcolors.CSS4_COLORS['red'], type(mcolors.CSS4_COLORS['red'])))

# 이름과 색코드가 별도의 형식으로 작성되어 있다.
# Out:
# mcolors.BASE_COLORS['r']: (1, 0, 0), type=<class 'tuple'>
# mcolors.TABLEAU_COLORS['tab:red']: #d62728, type=<class 'str'>
# mcolors.CSS4_COLORS['red']: #FF0000, type=<class 'str'>

# %%
# 색상 전체 명단 수집
colorlist = {}
colorlist.update(mcolors.BASE_COLORS)
colorlist.update(mcolors.TABLEAU_COLORS)
colorlist.update(mcolors.CSS4_COLORS)

# 색상 이름과 코드로 분리해서 관리
colornames = []
colorcodes = []
for name, color in colorlist.items():
    colornames.append(name)
    colorcodes.append(color)

# %%
import random

print(f'{random.sample(colornames, 10)}', '\n',  f'{random.sample(colorcodes, 10)}')
# Out:
# ['salmon', 'steelblue', 'm', 'mistyrose', 'darkturquoise', 'gold', 'tomato', 'aqua', 'w', 'violet']
#  ['#DAA520', '#A9A9A9', '#F5DEB3', '#D8BFD8', '#800080', '#EE82EE', '#00FF00', '#556B2F', '#6495ED', (0, 0.75, 0.75)]

# %%
mcolors.XKCD_COLORS
# Out:
# {'xkcd:cloudy blue': '#acc2d9',
#  'xkcd:dark pastel green': '#56ae57',
#  'xkcd:dust': '#b2996e',
#  'xkcd:electric lime': '#a8ff04',
#  'xkcd:fresh green': '#69d84f',
#  'xkcd:light eggplant': '#894585',
#  'xkcd:nasty green': '#70b23f',
#  'xkcd:really light blue': '#d4ffff',
#  'xkcd:tea': '#65ab7c',
#  'xkcd:warm purple': '#952e8f',
#  'xkcd:yellowish tan': '#fcfc81',
#  'xkcd:cement': '#a5a391',
#  'xkcd:dark grass green': '#388004',
#  'xkcd:dusty teal': '#4c9085',
#  'xkcd:grey teal': '#5e9b8a',
#  'xkcd:macaroni and cheese': '#efb435',
#  'xkcd:pinkish tan': '#d99b82',
#  'xkcd:spruce': '#0a5f38',
#  'xkcd:strong blue': '#0c06f7',
#  'xkcd:toxic green': '#61de2a',
#  'xkcd:windows blue': '#3778bf',
#  'xkcd:blue blue': '#2242c7',
#  'xkcd:blue with a hint of purple': '#533cc6',
#  'xkcd:booger': '#9bb53c',
#  'xkcd:bright sea green': '#05ffa6',
#  'xkcd:dark green blue': '#1f6357',
#  'xkcd:deep turquoise': '#017374',
#  'xkcd:green teal': '#0cb577',
# ...

# %%
data_x = np.array([0,20])
data_y = [0,10]

plt.plot(data_x, data_y, 'xkcd:dust')

# %%
data_x = np.array([0,20])
data_y = [0,10]

plt.plot(data_x, data_y, '#b2996e')

# %%
import matplotlib.pyplot as plt
import numpy as np

data_x = np.array([0,20])
data_y = [0,10]

fig, ax = plt.subplots(figsize=(6,3))
for i in range(12):
    ax.plot(data_x + 3*i, data_y)

plt.show() # 기본적으로 matplotlib의 색깔은 10개가 반복된다.

# %%
print(plt.rcParams['axes.prop_cycle'])
# Out:
# cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])

# %%
len(plt.rcParams['axes.prop_cycle'])
# Out:
# 10

# %% [markdown]
# 2. Cycler

# %%
# cycler 수정하기
from cycler import cycler
plt.rc('axes', prop_cycle=(cycler(color=['r', 'g', 'b', 'y']) +
                           cycler(linestyle=['-', '--', ':', '-.'])))

data_x = np.array([0,20])
data_y = [0,10]

fig, ax = plt.subplots(figsize=(15,3))
for i in range(12):
    ax.plot(data_x + 3*i, data_y)

plt.show()

# %%
data_x = np.array([0,20])
data_y = [0,10]

plt.plot(data_x, data_y, 'C0')  # cycler로 지정된 color는 CN -> C0 C1 C2 C3 C4  ... 선택이 가능

# %% [markdown]
# 3. Color Functions

# %%
import matplotlib.colors as mcolor

c1 = 'darkred'             # matplotlib color name
c2 = '#AABBFF'             # hex code without alpha  (16^2=256.   00 (0)~ FF(255) , 중간값 80(128)
c3 = '#AABBFF55'           # hex code with alpha
c4 = [0.2, 0.4, 0.5]       # RGB
c5 = [0.2, 0.4, 0.5, 0.6]  # RGBA: RGB + alpha

# %%
import pandas as pd

colors = pd.DataFrame(columns=['input', 'to_hex(F)', 'to_hex(T)', 
                               'to_rgb()', 'to_rgba(alpha=None)', 'to_rgba(alpha=0.2)'])

for i in range(5):
    # to_hex()
    hex_code0 = mcolors.to_hex(eval(f'c{i+1}'), keep_alpha=False)
    hex_code1 = mcolors.to_hex(eval(f'c{i+1}'), keep_alpha=True)
    
    # to_rgb()
    rgb_code0 = np.round(mcolors.to_rgb(eval(f'c{i+1}')), 3)
    
    # to_rgba()
    rgb_code1 = np.round(mcolors.to_rgba(eval(f'c{i+1}')), 3)
    rgb_code2 = np.round(mcolors.to_rgba(eval(f'c{i+1}'), 0.2), 3)
    
    colors.loc[i] = [eval(f'c{i+1}'), hex_code0, hex_code1, rgb_code0, rgb_code1, rgb_code2]

# %%
colors
# Out:
#                   input to_hex(F)  to_hex(T)             to_rgb()  \
# 0               darkred   #8b0000  #8b0000ff    [0.545, 0.0, 0.0]
# 1               #AABBFF   #aabbff  #aabbffff  [0.667, 0.733, 1.0]
# 2             #AABBFF55   #aabbff  #aabbff55  [0.667, 0.733, 1.0]
# 3       [0.2, 0.4, 0.5]   #336680  #336680ff      [0.2, 0.4, 0.5]
# 4  [0.2, 0.4, 0.5, 0.6]   #336680  #33668099      [0.2, 0.4, 0.5]
#
#           to_rgba(alpha=None)        to_rgba(alpha=0.2)
# 0      [0.545, 0.0, 0.0, 1.0]    [0.545, 0.0, 0.0, 0.2]
# 1    [0.667, 0.733, 1.0, 1.0]  [0.667, 0.733, 1.0, 0.2]
# 2  [0.667, 0.733, 1.0, 0.333]  [0.667, 0.733, 1.0, 0.2]
# 3        [0.2, 0.4, 0.5, 1.0]      [0.2, 0.4, 0.5, 0.2]
# 4        [0.2, 0.4, 0.5, 0.6]      [0.2, 0.4, 0.5, 0.2]

# %% [markdown]
# 4. Colormap

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()

# %%
housing
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
housing.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %%
df = pd.DataFrame (housing.data, columns = housing.feature_names)
df['target'] = housing.target   # (8,20640) , (20640,) ...

# %%
df.columns[:-1]
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
fig, axes = plt.subplots(figsize=(10,6), ncols=4, nrows=2)

axes = axes.ravel()

for i, col in enumerate(df.columns[:-1]):  # DataFrame을 순회하면 column을 차례대로 뱉는다.
    axes[i].scatter(df[col] , df['target'], s=3, c='C1')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('target')
    
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

im = ax.scatter(df['MedInc'], df['target'], s=5, c=df['Latitude'], cmap='jet', alpha=0.5)
ax.set_xlabel('MedInc')
ax.set_ylabel('target')

c_bar = plt.colorbar(im, ax=ax, orientation='horizontal', aspect=100, fraction=0.2, ticks=[34,35,36,37,38,39,40], format='%1.0f', drawedges=False)
c_bar.set_label('longitude')
plt.tight_layout(rect=(0, 0, 1, 1)) # left, bottom, right, top
plt.show()

# %%
image_path = r"C:\Users\inbody\Desktop\cat.jpg"
image = Image.open(image_path)
imarray = np.array(image)
print(imarray.shape)
plt.imshow(image)
# Out:
# (175, 287, 3)

# %%
import cv2

image_path = r"C:\Users\inbody\Downloads\4_cmap_16.tif"
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image


image_path = r"C:\Users\inbody\Downloads\4_cmap_16.tif"
image = Image.open(image_path)
print(image.mode)
imarray = np.array(image)
print(imarray.shape)

plt.imshow(imarray, cmap='viridis')
# Out:
# P
# (720, 1440)
