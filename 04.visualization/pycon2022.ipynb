# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seaborn을 이용한 환경설정

sns.set_context("notebook") #font, line, marker를 일괄적으로 조정 {paper, notebook, talk, poster}
# Calling this function modifies the global matplotlib

sns.set_palette("Set2")
sns.set_style("whitegrid") # {darkgrid, whitegrid, dark, white, ticks}

# %% [markdown]
# mission1 : matplotlib을 seaborn처럼 꾸미기

# %%
import matplotlib.font_manager as fm  # 폰트 관련 용도
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

# %%
import matplotlib
matplotlib.get_cachedir()
# Out:
# 'C:\\Users\\inbody\\.matplotlib'

# %%
font_path = r'C:\Users\inbody\AppData\Local\Microsoft\Windows\Fonts\PretendardVariable.ttf'
font_name = plt.matplotlib.font_manager.FontProperties(fname=font_path).get_name()

# %%
plt.rcParams['figure.figsize'] = (5,5)
plt.rcParams['figure.dpi'] = 72
plt.rcParams['lines.linewidth'] = 4
plt.rcParams['axes.grid'] = True

plt.rcParams['savefig.dpi'] = 200
plt.rcParams['savefig.transparent'] = True

# plt.rcParams['font.family'] = 'Dejavu Sans'
plt.rcParams['font.family'] = font_name
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.size'] = 14

# %%
df_peng = sns.load_dataset('penguins')

# %%
x, y = df_peng["bill_length_mm"] , df_peng["bill_depth_mm"]

# %%
plt.scatter(x,y)
#plt.figure(figsize=(4,3))

# %%
plt.scatter(x,y, alpha=0.6)
#plt.figure(figsize=(4,3))

# %% [markdown]
# mission 2. 모범 사례 시각화
# - 상태 기반(stateful) 명령어 대신 객체 기반(obeject-oriented) 명령어로 가능
# - figure / axes / artist / properties

# %%
import numpy as np
x = np.random.rand(15) * 10
x.sort()
y = x**2
plt.plot(x, y, marker = "o", ms=10, label="power")

# %%
fig, axes = plt.subplots(ncols = 2, figsize=(8,4),
                         gridspec_kw={"wspace" : 0.1},
                         constrained_layout=True)

axes[0].scatter(x,y)
axes[1].scatter(x,y)
for ax in axes : 
    ax.set_title("Plot Visualization")
    ax.set_xlabel('xlabel')

fig.suptitle("슈퍼타이틀")
# Out:
# Text(0.5, 0.98, '슈퍼타이틀')
