# %%
char = 'g'

for i in range(1001):
    num = i * 0.1
    space = ' '
    text = f'{num:.1f}' + space + char
    print(text)
# Out:
# 0.0 g
# 0.1 g
# 0.2 g
# 0.3 g
# 0.4 g
# 0.5 g
# 0.6 g
# 0.7 g
# 0.8 g
# 0.9 g
# 1.0 g
# 1.1 g
# 1.2 g
# 1.3 g
# 1.4 g
# 1.5 g
# 1.6 g
# 1.7 g
# 1.8 g
# 1.9 g
# 2.0 g
# 2.1 g
# 2.2 g
# 2.3 g
# 2.4 g
# 2.5 g
# 2.6 g
# 2.7 g
# 2.8 g
# 2.9 g
# 3.0 g
# 3.1 g
# 3.2 g
# 3.3 g
# 3.4 g
# 3.5 g
# 3.6 g
# 3.7 g
# 3.8 g
# 3.9 g
# 4.0 g
# 4.1 g
# 4.2 g
# 4.3 g
# 4.4 g
# 4.5 g
# 4.6 g
# 4.7 g
# 4.8 g
# 4.9 g
# 5.0 g
# 5.1 g
# 5.2 g
# 5.3 g
# 5.4 g
# 5.5 g
# 5.6 g
# 5.7 g
# 5.8 g
# 5.9 g
# 6.0 g
# 6.1 g
# 6.2 g
# 6.3 g
# 6.4 g
# 6.5 g
# 6.6 g
# 6.7 g
# 6.8 g
# 6.9 g
# 7.0 g
# 7.1 g
# 7.2 g
# 7.3 g
# 7.4 g
# 7.5 g
# 7.6 g
# 7.7 g
# 7.8 g
# 7.9 g
# 8.0 g
# 8.1 g
# 8.2 g
# 8.3 g
# 8.4 g
# 8.5 g
# 8.6 g
# 8.7 g
# 8.8 g
# 8.9 g
# 9.0 g
# 9.1 g
# 9.2 g
# 9.3 g
# 9.4 g
# 9.5 g
# 9.6 g
# 9.7 g
# 9.8 g
# 9.9 g
# 10.0 g
# 10.1 g
# 10.2 g
# 10.3 g
# 10.4 g
# 10.5 g
# 10.6 g
# 10.7 g
# 10.8 g
# 10.9 g
# 11.0 g
# 11.1 g
# 11.2 g
# 11.3 g
# 11.4 g
# 11.5 g
# 11.6 g
# 11.7 g
# 11.8 g
# 11.9 g
# 12.0 g
# 12.1 g
# ...

# %%
for i in range(1001,5000):
    num = str(i)
    marker = ','
    text = num[:3] + marker + num[3:]
    print(text)
# Out:
# 100,1
# 100,2
# 100,3
# 100,4
# 100,5
# 100,6
# 100,7
# 100,8
# 100,9
# 101,0
# 101,1
# 101,2
# 101,3
# 101,4
# 101,5
# 101,6
# 101,7
# 101,8
# 101,9
# 102,0
# 102,1
# 102,2
# 102,3
# 102,4
# 102,5
# 102,6
# 102,7
# 102,8
# 102,9
# 103,0
# 103,1
# 103,2
# 103,3
# 103,4
# 103,5
# 103,6
# 103,7
# 103,8
# 103,9
# 104,0
# 104,1
# 104,2
# 104,3
# 104,4
# 104,5
# 104,6
# 104,7
# 104,8
# 104,9
# 105,0
# 105,1
# 105,2
# 105,3
# 105,4
# 105,5
# 105,6
# 105,7
# 105,8
# 105,9
# 106,0
# 106,1
# 106,2
# 106,3
# 106,4
# 106,5
# 106,6
# 106,7
# 106,8
# 106,9
# 107,0
# 107,1
# 107,2
# 107,3
# 107,4
# 107,5
# 107,6
# 107,7
# 107,8
# 107,9
# 108,0
# 108,1
# 108,2
# 108,3
# 108,4
# 108,5
# 108,6
# 108,7
# 108,8
# 108,9
# 109,0
# 109,1
# 109,2
# 109,3
# 109,4
# 109,5
# 109,6
# 109,7
# 109,8
# 109,9
# 110,0
# 110,1
# 110,2
# 110,3
# 110,4
# 110,5
# 110,6
# 110,7
# 110,8
# 110,9
# 111,0
# 111,1
# 111,2
# 111,3
# 111,4
# 111,5
# 111,6
# 111,7
# 111,8
# 111,9
# 112,0
# 112,1
# 112,2
# 112,3
# 112,4
# 112,5
# ...
